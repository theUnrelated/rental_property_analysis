# %%
import pandas as pd

# %%
df1 = pd.read_csv('resale-flat-prices-based-on-approval-date-2000-feb-2012.csv')
df2 = pd.read_csv('resale-flat-prices-based-on-registration-date-from-mar-2012-to-dec-2014.csv')
df3 = pd.read_csv('resale-flat-prices-based-on-registration-date-from-jan-2015-onwards.csv')

# %%
df4 = pd.read_csv('mergedHDB2.csv')

# %%
column = [col for col in df4.columns if 'Nearest'  in col]

# %%
df4 = df4.drop(['block', 'flat_model', 'remaining_lease', 'street_name', 'area', 'storey_range']  + column, axis= 1)

# %%
df = pd.concat([df1,df2,df3])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
mapp = pd.read_csv('area_mapping.csv')

# %%
mapp = mapp.iloc[:,1:]

# %%
columns = [col for col in mapp.columns if ('ratio' not in col and 'total' not in col)]
columns  = [col for col in columns if ('education' in col or 'income' in col or 'dwelling' in col or 'area' in col)]

# %%
mapp = mapp.loc[:, columns]

# %%
df.head()
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   216  New Generation    3 ROOM            73.0                 1976
# 1   215  New Generation    3 ROOM            73.0                 1976
# 2   218  New Generation    3 ROOM            67.0                 1976
# 3   304  New Generation    4 ROOM            97.0                 1977
# 4   221        Improved    5 ROOM           127.0                 1993
#
#      month  remaining_lease  resale_price storey_range       street_name  \
# 0  2000-01              NaN      159000.0     07 TO 09  ANG MO KIO AVE 1
# 1  2000-01              NaN      167000.0     07 TO 09  ANG MO KIO AVE 1
# 2  2000-01              NaN      163000.0     07 TO 09  ANG MO KIO AVE 1
# 3  2000-01              NaN      260000.0     04 TO 06  ANG MO KIO AVE 1
# 4  2000-01              NaN      408000.0     10 TO 12  ANG MO KIO AVE 1
#
#          town
# 0  ANG MO KIO
# 1  ANG MO KIO
# 2  ANG MO KIO
# 3  ANG MO KIO
# 4  ANG MO KIO

# %%
a = [mapp.area.str.split(',', expand=  True)[i].unique() for i in range (5)]

# %%
towns = []
town.append(i) for i in range(5) f
# Out:
# [array(['BUKIT MERAH', 'BUKIT TIMAH', 'NOVENA', 'TOA PAYOH', 'KALLANG',
#         'MARINE PARADE', 'BEDOK', 'PASIR RIS', 'HOUGANG', 'ANG MO KIO',
#         'CLEMENTI', 'PIONEER', 'BUKIT PANJANG', 'MANDAI', 'YISHUN'],
#        dtype=object),
#  array(['OUTRAM', 'TANGLIN', 'NEWTON', None, 'GEYLANG', 'MARINA EAST',
#         'TAMPINES', 'SENGKANG', 'BISHAN', 'JURONG WEST', 'BUKIT BATOK',
#         'WOODLANDS', 'SEMBAWANG'], dtype=object),
#  array(['QUEENSTOWN', None, 'PAYA LEBAR', 'SERANGOON', 'JURONG EAST',
#         'CHOA CHU KANG'], dtype=object),
#  array([None, 'PUNGGOL', 'BOON LAY'], dtype=object),
#  array([None, 'TUAS'], dtype=object)]

# %%
town = []
for i in range(5):
    town.extend(list(a[i]))

# %%
town = list(set(town))

# %%
mapp = mapp.drop_duplicates('area')

# %%
town = pd.DataFrame(town)

# %%
x = town.merge(mapp, left_on = 0, right_on = 0)

# %%
x.append(town.merge(mapp,))
# Out:
#                 0                                           area  \
# 0       TOA PAYOH                                      TOA PAYOH
# 1       PASIR RIS                             PASIR RIS,TAMPINES
# 2           BEDOK                                          BEDOK
# 3        CLEMENTI                                       CLEMENTI
# 4          MANDAI                               MANDAI,WOODLANDS
# 5   BUKIT PANJANG        BUKIT PANJANG,BUKIT BATOK,CHOA CHU KANG
# 6     BUKIT TIMAH                            BUKIT TIMAH,TANGLIN
# 7          NOVENA                                  NOVENA,NEWTON
# 8         KALLANG                     KALLANG,GEYLANG,PAYA LEBAR
# 9   MARINE PARADE                      MARINE PARADE,MARINA EAST
# 10        PIONEER  PIONEER,JURONG WEST,JURONG EAST,BOON LAY,TUAS
# 11    BUKIT MERAH                  BUKIT MERAH,OUTRAM,QUEENSTOWN
# 12        HOUGANG             HOUGANG,SENGKANG,SERANGOON,PUNGGOL
# ...

# %%
town1 = town.merge(mapp, left_on = 0, right_on = 1, how = 'inner').rename(columns = {'0_x': 0})
# Out:
#           key_0            0                                           area  \
# 0       TANGLIN      TANGLIN                            BUKIT TIMAH,TANGLIN
# 1       GEYLANG      GEYLANG                     KALLANG,GEYLANG,PAYA LEBAR
# 2        NEWTON       NEWTON                                  NOVENA,NEWTON
# 3   MARINA EAST  MARINA EAST                      MARINE PARADE,MARINA EAST
# 4   BUKIT BATOK  BUKIT BATOK        BUKIT PANJANG,BUKIT BATOK,CHOA CHU KANG
# 5     WOODLANDS    WOODLANDS                               MANDAI,WOODLANDS
# 6        BISHAN       BISHAN                              ANG MO KIO,BISHAN
# 7      TAMPINES     TAMPINES                             PASIR RIS,TAMPINES
# 8     SEMBAWANG    SEMBAWANG                               YISHUN,SEMBAWANG
# 9        OUTRAM       OUTRAM                  BUKIT MERAH,OUTRAM,QUEENSTOWN
# 10     SENGKANG     SENGKANG             HOUGANG,SENGKANG,SERANGOON,PUNGGOL
# ...

# %%
town1 = town.merge(mapp, left_on = 0, right_on = 1, how = 'inner').rename(columns = {'0_x': 0})
town2 = town.merge(mapp, left_on = 0, right_on = 2, how = 'inner').rename(columns = {'0_x': 0})
town3 = town.merge(mapp, left_on = 0, right_on = 3, how = 'inner').rename(columns = {'0_x': 0})
town4 = town.merge(mapp, left_on = 0, right_on = 4, how = 'inner').rename(columns = {'0_x': 0})

# %%
# Out:
# 'ANG MO KIO'

# %%
x = town.merge(mapp, left_on = 0, right_on = 0, how = 'inner').rename(columns = {'0_x': 0})

# %%
dfx = pd.concat([x,town1,town2,town3,town4])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
final_map = dfx.iloc[:, :-6]

# %%
df2 = df.merge(final_map, left_on = 'town', right_on = 0, how = 'left')

# %%
df2.loc[df2[0].isnull()]
# Out:
#        block      flat_model  flat_type  floor_area_sqm  lease_commence_date  \
# 658      668         Model A     3 ROOM            73.0                 1984
# 659        8        Improved     3 ROOM            76.0                 1971
# 660        8        Improved     3 ROOM            76.0                 1971
# 661       28        Improved     3 ROOM            74.0                 1977
# 662       30        Improved     3 ROOM            66.0                 1981
# 663      334        Improved     4 ROOM            83.0                 1981
# 664     269A  New Generation     3 ROOM            67.0                 1984
# 665        3  New Generation     3 ROOM            67.0                 1977
# 666      640         Model A     3 ROOM            74.0                 1984
# 667        4        Improved     3 ROOM            67.0                 1974
# 668        5        Improved     3 ROOM            59.0                 1977
# ...

# %%
df = df.drop(['block', 'street_name', 'storey_range', 'remaining_lease'], axis = 1)

# %%
df.month.str.split('-', expand = True)[0]
# Out:
# 0        2000
# 1        2000
# 2        2000
# 3        2000
# 4        2000
# 5        2000
# 6        2000
# 7        2000
# 8        2000
# 9        2000
# 10       2000
# 11       2000
# 12       2000
# 13       2000
# 14       2000
# 15       2000
# 16       2000
# 17       2000
# 18       2000
# 19       2000
# 20       2000
# 21       2000
# 22       2000
# 23       2000
# 24       2000
# 25       2000
# 26       2000
# 27       2000
# 28       2000
# 29       2000
#          ...
# 80615    2019
# 80616    2019
# 80617    2019
# 80618    2019
# 80619    2019
# 80620    2019
# 80621    2019
# 80622    2019
# 80623    2019
# 80624    2019
# 80625    2019
# 80626    2019
# 80627    2019
# 80628    2019
# 80629    2019
# 80630    2019
# 80631    2019
# 80632    2019
# 80633    2019
# 80634    2019
# 80635    2019
# 80636    2019
# 80637    2019
# 80638    2019
# 80639    2019
# 80640    2019
# 80641    2019
# 80642    2019
# 80643    2019
# 80644    2019
# ...

# %%
df4
# Out:
# Index(['flat_type', 'floor_area_sqm', 'lease_commence_date', 'month',
#        'resale_price', 'town', 'income_below_sgd_1000',
#        'income_no_working_person', 'income_sgd_10000_to_10999',
#        'income_sgd_1000_to_1999', 'income_sgd_11000_to_11999',
#        'income_sgd_12000_to_12999', 'income_sgd_13000_to_13999',
#        'income_sgd_14000_to_14999', 'income_sgd_15000_to_17499',
#        'income_sgd_17500_to_19999', 'income_sgd_20000_over',
#        'income_sgd_2000_to_2999', 'income_sgd_3000_to_3999',
#        'income_sgd_4000_to_4999', 'income_sgd_5000_to_5999',
#        'income_sgd_6000_to_6999', 'income_sgd_7000_to_7999',
#        'income_sgd_8000_to_8999', 'income_sgd_9000_to_9999', 'lat', 'lon',
#        'Distance_mrt(km)', 'Distance_sch(km)', 'Distance_mall(km)',
#        'Distance_cbd(km)', 'Distance_uni(km)'],
#       dtype='object')

# %%
df4.month.head()
# Out:
# 0    2000-01
# 1    2000-01
# 2    2000-01
# 3    2000-01
# 4    2000-01
# Name: month, dtype: object

# %%
df4.month  = df4.month.str.split('-', expand = True)[0]

# %%
df4  = df4.rename(columns = {'month':'year'})

# %%
df4 = df4.groupby(['town', 'flat_type','year']).mean().reset_index()

# %%
df4['age'] = 2019 - df4.lease_commence_date

# %%
df4.year = pd.to_numeric(df4.year)

# %%
df4["year_no"] = df4.year - 1999

# %%
df4 = df4.groupby(['town', 'flat_type']).apply(lambda x: x.assign(price_past_10 = lambda y: y.resale_price.shift(10)))
df4 = df4.groupby(['town', 'flat_type']).apply(lambda x: x.assign(price_past_9 = lambda y: y.resale_price.shift(9)))
df4 = df4.groupby(['town', 'flat_type']).apply(lambda x: x.assign(price_past_8 = lambda y: y.resale_price.shift(8)))
df4 = df4.groupby(['town', 'flat_type']).apply(lambda x: x.assign(price_past_7 = lambda y: y.resale_price.shift(7)))
df4 = df4.groupby(['town', 'flat_type']).apply(lambda x: x.assign(price_past_6 = lambda y: y.resale_price.shift(6)))
df4 = df4.groupby(['town', 'flat_type']).apply(lambda x: x.assign(price_past_5 = lambda y: y.resale_price.shift(5)))
df4 = df4.groupby(['town', 'flat_type']).apply(lambda x: x.assign(price_past_4 = lambda y: y.resale_price.shift(4)))
df4 = df4.groupby(['town', 'flat_type']).apply(lambda x: x.assign(price_past_3 = lambda y: y.resale_price.shift(3)))
df4 = df4.groupby(['town', 'flat_type']).apply(lambda x: x.assign(price_past_2 = lambda y: y.resale_price.shift(2)))
df4 = df4.groupby(['town', 'flat_type']).apply(lambda x: x.assign(price_past_1 = lambda y: y.resale_price.shift(1)))
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: 'town' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: 'flat_type' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'town' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'flat_type' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
# ...

# %%
df4 = df4.reset_index(drop = True)

# %%
df4 = df4[df4.year_no > 10]

# %%
df4 = df4.dropna()

# %%
df4_target = df4.groupby(['town', 'flat_type']).apply(lambda x: x.assign(price_target = lambda y: y.resale_price.shift(-5)))
df4_target = df4_target.reset_index(drop = True)

# %%
df4_target['target year'] = df4_target.year + 5

# %%
df4_target_dummy = pd.get_dummies(df4_target)

# %%
df4_target_train = df4_target_dummy[~df4_target_dummy.price_target.isnull()]
df4_target_predict = df4_target_dummy[df4_target_dummy.price_target.isnull()]

# %%
df4_target_predict = df4_target_predict[df4_target_predict['target year'] > 2018].drop('price_target', axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split( df4_target_train.drop(['year', 'target year', 'price_target'], axis = 1) , df4_target_train['price_target'], test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.ensemble import AdaBoostRegressor, BaggingRegressor, GradientBoostingRegressor, RandomForestRegressor

# %%
reg = LinearRegression()
reg = reg.fit(X_train, y_train)
reg.score(X_test, y_test)
# Out:
# 0.9689998492321941

# %%
ada = AdaBoostRegressor()
ada = ada.fit(X_train, y_train)
ada.score(X_test,y_test)
# Out:
# 0.956002631208211

# %%
bag = BaggingRegressor()
bag = bag.fit(X_train, y_train)
bag.score(X_test,y_test)
# Out:
# 0.9754944756363059

# %%
gbm = GradientBoostingRegressor()
gbm = bag.fit(X_train, y_train)
gbm.score(X_test,y_test)
# Out:
# 0.9742201189056208

# %%
rfm = RandomForestRegressor()
rfm = bag.fit(X_train, y_train)
rfm.score(X_test,y_test)
# Out:
# 0.9716744216922603

# %%
df4_target_predict['predicted_target'] = gbm.predict(df4_target_predict)

# %%
len(df4_target_predict)
# Out:
# 542

# %%
df4_target_predict_nodum = df4_target[df4_target.price_target.isnull()]

# %%
df4_target_predict_nodum = df4_target_predict_nodum[df4_target_predict_nodum['target year'] > 2018].drop('price_target', axis = 1)

# %%
df4_target_predict_nodum['predicted_target'] = df4_target_predict['predicted_target']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df4_target_predict_nodum = df4_target_predict_nodum.drop('price_target', axis = 1)

# %%
df4_target_predict_nodum = df4_target_predict_nodum.rename(columns = {'predicted_target': 'price_target'})

# %%
final_df =df4_target_predict_nodum

# %%
final_df = final_df.reset_index().drop('index', axis = 1)

# %%
lst = []
for i, row in final_df.iterrows():
    
    town_df = final_df[final_df['town'] == row['town']]
    flat_df = town_df[town_df['flat_type'] == row['flat_type']]
    last_year = flat_df['year'].unique().max()
    price_last = flat_df[flat_df['year'] == last_year]['resale_price']
    lst.append((row['price_target'] - price_last))

# %%
lst = [int(lst[i]) for i in range(len(lst))]

# %%
len(final_df)
# Out:
# 542

# %%
final_df['diff_price18'] = lst
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
final_df = pd.read_csv('final.csv')

# %%
final_df = final_df.iloc[:, 1:]

# %%
final_df['lat'] = final_df['lat'].apply(lambda x: round(x, 4))

# %%
final_df['lon'] = final_df['lon'].apply(lambda x: round(x, 4))

# %%
final_df.to_csv('final2.csv')

# %%
lat_lon = final_df[['town', 'lat', 'lon']].drop_duplicates()

# %%
lat_lon.to_csv('latlon.csv')

# %%
dfy = pd.read_csv('pgTowns.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (14,15,16,17,18,21,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dfy.head()
# Out:
#    Unnamed: 0 Property Website Title  \
# 0           0            99.co   NaN
# 1           1            99.co   NaN
# 2           2            99.co   NaN
# 3           3            99.co   NaN
# 4           4            99.co   NaN
#
#                                              Address  Postal Code  District  \
# 0  # 1 Loft Aljunied MRT 5 min (411m) Lorong 24 G...          NaN        14
# 1  # 1 Loft Aljunied MRT 5 min (411m) Lorong 24 G...          NaN        14
# 2  # 1 Suites Aljunied MRT 6 min (476m) Lorong 20...          NaN        14
# 3                     # 1 Suites Lorong 20 Geylang,           NaN        14
# 4                                  1 Balestier Road           NaN        12
#
#         town     lat       lon                 Size ...  LandSize Latitude  \
# 0    GEYLANG  1.3201  103.8918  571 sqft (built up) ...       NaN      NaN
# 1    GEYLANG  1.3201  103.8918  581 sqft (built up) ...       NaN      NaN
# ...
